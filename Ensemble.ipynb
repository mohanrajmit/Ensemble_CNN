# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanrajmit/Ensemble_CNN/blob/master/Ensemble.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# keras imports
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.applications.xception import Xception, preprocess_input
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras.preprocessing import image
from keras.models import Model
from keras.models import model_from_json
from keras.layers import Input
# Out:
# Using TensorFlow backend.

# %% [markdown]
# CNN Pretrained model for feature extraction and concatenation of feature vector from VGG and Xception model

# %%
# other imports
from sklearn.preprocessing import LabelEncoder
import numpy as np
import glob
import cv2
import h5py
import os
import json
import datetime
import time
import pandas as pd

# %%
# create the pretrained models
# check for pretrained weight usage or not
# check for top layers to be included or not
base_model_vgg = VGG16(weights="imagenet")
model_vgg = Model(input=base_model_vgg.input, output=base_model_vgg.get_layer('fc1').output)
image_size_vgg = (224, 224)

base_model_xception = Xception(weights="imagenet")
model_xception = Model(input=base_model_xception.input, output=base_model_xception.get_layer('avg_pool').output)
image_size_xception = (299, 299)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("fc...)`
#
# W0715 15:24:05.982723 140146664183680 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.4/xception_weights_tf_dim_ordering_tf_kernels.h5
# 91889664/91884032 [==============================] - 4s 0us/step
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("av...)`

# %%
# !git clone https://github.com/mohanrajmit/AGE_ESTIMATION.git
# Out:
# fatal: destination path 'AGE_ESTIMATION' already exists and is not an empty directory.

# %%
train_path = "AGE_ESTIMATION/dataset/train"
train_labels = os.listdir("AGE_ESTIMATION/dataset/train")

# %%
train_labels
# Out:
# ['Middle', 'Young', 'Old']

# %%
# variables to hold features and labels
features = []
labels   = []

# loop over all the labels in the folder
count = 1
for i, label in enumerate(train_labels):
  cur_path = train_path + "/" + label
  count = 1
  for image_path in glob.glob(cur_path + "/*.jpg"):
    img_vgg = image.load_img(image_path, target_size=image_size_vgg)
    x_vgg = image.img_to_array(img_vgg)
    x_vgg = np.expand_dims(x_vgg, axis=0)
    x_vgg = preprocess_input(x_vgg)
    feature_vgg = model_vgg.predict(x_vgg)
    
    flat_vgg = feature_vgg.flatten()
    #print(flat_vgg.shape)
    img_xception = image.load_img(image_path, target_size=image_size_xception)
    x_xception = image.img_to_array(img_xception)
    x_xception = np.expand_dims(x_xception, axis=0)
    x_xception = preprocess_input(x_xception)
    feature_xception = model_xception.predict(x_xception)
    flat_xception = feature_xception.flatten()
    #print(flat_xception.shape)
    
    concat_feature = np.concatenate((flat_vgg, flat_xception), axis=0)
    print(concat_feature.shape)  
    features.append(concat_feature)
    labels.append(label)
# Out:
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# ...
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)
# (6144,)

# %%
print(np.array(features).shape)
print(len(labels))
# Out:
# (15923, 6144)
# 15923
